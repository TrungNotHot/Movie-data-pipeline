# %%
import numpy as np
import pandas as pd

# %%
pd.read_json('raw/metadata.json',lines=True)
# Out:
#                                                    title  \
# 0                                       Toy Story (1995)
# 1                                         Jumanji (1995)
# 2                                Grumpier Old Men (1995)
# 3                               Waiting to Exhale (1995)
# 4                     Father of the Bride Part II (1995)
# ...                                                  ...
# 84656                             The Tenth Level (1976)
# 84657                                   Nightmare (1974)
# 84658                                     Pee Nak (2019)
# 84659                                   Pee Nak 2 (2020)
# 84660  The Making of the Philadelphia Eagles Cheerlea...
#
#                          directedBy  \
# 0                     John Lasseter
# 1                      Joe Johnston
# 2                     Howard Deutch
# 3                   Forest Whitaker
# 4                     Charles Shyer
# ...                             ...
# ...

# %%
pd.read_json('raw/survey_answers.json',lines=True)
# Out:
#        user_id  item_id  tag_id  score
# 0       978707     3108   50126      3
# 1       978707     2858   50126      1
# 2       978707     1269   50126      1
# 3       978707     1136   50126      1
# 4       978707     1220   50126      1
# ...        ...      ...     ...    ...
# 58898   705354    56949   91482      1
# 58899   705354     7255   91482      2
# 58900   705354    54276   91482      5
# 58901   705354    55267   91482      2
# 58902   705354    42732   91482      3
#
# [58903 rows x 4 columns]

# %%
pd.read_json('raw/tag_count.json',lines=True)
# Out:
#         item_id  tag_id  num
# 0             1   86963    4
# 1             1   42940    1
# 2             1   37116   26
# 3             1   52206    1
# 4             1   34442   21
# ...         ...     ...  ...
# 212699   239042   53302    1
# 212700   239044    9953    1
# 212701   239044   51676    1
# 212702   239044   46718    1
# 212703   239044   52817    1
#
# [212704 rows x 3 columns]

# %%
pd.read_json('raw/tags.json',lines=True)
# Out:
#                  tag      id
# 0            aardman      22
# 1     secret service     112
# 2         hillarious     167
# 3          christian     270
# 4              mummy     362
# ...              ...     ...
# 1089   disappointing  109147
# 1090         lesbian  109249
# 1091        morality  109333
# 1092     new orleans  109336
# 1093         bad cgi  109660
#
# [1094 rows x 2 columns]
